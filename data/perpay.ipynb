# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# set view options for pandas DataFrame to null


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
product_df = pd.read_csv("product_catalog.csv")
orders_df = pd.read_csv("user_order_history.csv")

# %%
product_df.head()
# Out:
#    product_id                                               name  \
# 0      417366                       Adesso - Orbit 1120 Dash Cam
# 1      306271  PetSafe - Rechargeable Fence System 14 gauge W...
# 2      409248  Bloem - Mathers Round Planter with Saucer Tray...
# 3      334555        Yokohama - Geolandar M/T G003 - LT255/75R17
# 4      339738             ScooterX - Dirt Dog 49cc Scooter - Red
#
#   product_added_date     brand    current_vendor          category_name_1  \
# 0         2024-09-04    Adesso               D&H                     Auto
# 1         2019-04-12   PetSafe  UTM Distributing                     Home
# 2         2024-06-19     Bloem        Flat River  Outdoor Living & Garden
# 3         2020-10-19  Yokohama       Simple Tire                     Auto
# 4         2021-03-09  ScooterX      Big Toys USA              Baby & Kids
#
#          request_path_1 category_name_2                    request_path_2  \
# ...

# %%
orders_df.head()
# Out:
#    user_id  order_id order_carted_date order_checkout_date order_denied_date  \
# 0     6456   9187009        2025-06-30          2025-06-30               NaN
# 1    25844   9187819        2025-06-30          2025-06-30               NaN
# 2    25844   9187819        2025-06-30          2025-06-30               NaN
# 3    25844   9187819        2025-06-30          2025-06-30               NaN
# 4    38948   9183274        2025-06-30          2025-06-30               NaN
#
#   order_approved_date order_in_repayment_date order_refunded_date  \
# 0          2025-06-30              2025-06-30                 NaN
# 1          2025-06-30              2025-06-30                 NaN
# 2          2025-06-30              2025-06-30                 NaN
# 3          2025-06-30              2025-06-30                 NaN
# 4          2025-06-30              2025-06-30                 NaN
#
#   order_canceled_date order_complete_date  product_id
# ...

# %%
orders_df.loc[(orders_df["user_id"] == 25844)]
# Out:
#          user_id  order_id order_carted_date order_checkout_date  \
# 1          25844   9187819        2025-06-30          2025-06-30
# 2          25844   9187819        2025-06-30          2025-06-30
# 3          25844   9187819        2025-06-30          2025-06-30
# 1191627    25844   8468106        2025-02-11          2025-02-11
# 1191628    25844   8468106        2025-02-11          2025-02-11
# 1191629    25844   8468106        2025-02-11          2025-02-11
# 1191630    25844   8468106        2025-02-11          2025-02-11
# 1435137    25844   8320259        2025-01-13          2025-01-13
# 1435138    25844   8320259        2025-01-13          2025-01-13
#
#         order_denied_date order_approved_date order_in_repayment_date  \
# 1                     NaN          2025-06-30              2025-06-30
# 2                     NaN          2025-06-30              2025-06-30
# 3                     NaN          2025-06-30              2025-06-30
# ...

# %%
product_df.loc[(product_df["product_id"] == 441726)]
# Out:
#         product_id                                                 name  \
# 148023      441726  Living Proof - Perfect Hair Day Conditioner, 24 oz.
#
#        product_added_date         brand current_vendor category_name_1  \
# 148023         2025-06-24  LIVING PROOF     IGL Brands          Beauty
#
#        request_path_1 category_name_2   request_path_2 category_name_3  \
# 148023         beauty       Hair Care  beauty/haircare   Hair Products
#
#                       request_path_3 category_name_4 request_path_4  \
# 148023  beauty/haircare/hairproducts             NaN            NaN
#
#                                        product_url  parent_product_id  \
# 148023  https://app.perpay.com/shop/product/441726                NaN
#
#         current_price  current_cost  current_margin  current_ship_price  msrp  \
# 148023          79.99         39.91           40.08               17.99  67.0
#
#         comparable_price  current_inventory current_status  \
# ...
